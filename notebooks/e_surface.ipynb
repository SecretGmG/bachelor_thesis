# %%
import numpy as np
import pyvista as pv
# Out:
# Widget(value='<iframe src="http://localhost:38203/index.html?ui=P_0x779c000103b0_1&reconnect=auto" class="pyvi…

# %%
def e_surf(k, q, m1, m2):
    return (
        np.sqrt(np.sum((k - q[1:]) ** 2, axis=-1) + m1**2)
        + np.sqrt(np.sum((k + q[1:]) ** 2, axis=-1) + m2**2)
        - 2 * q[0]
    )

# %%
res = 100
x = y = z = np.linspace(-1.2, 1.2, res)

ks = np.stack(np.meshgrid(x, y, z), axis = -1)

vals = e_surf(ks, np.array([1,0,0,0.5]), 0.3, 0.5)

grid = pv.ImageData()
grid.dimensions = np.array(vals.shape)
grid.origin = (x[0], y[0], z[0])
grid.spacing = (x[1] - x[0], y[1] - y[0], z[1] - z[0])

grid.point_data["vals"] = vals.flatten(order="F")
surf = grid.contour([0])

plotter = pv.Plotter()
plotter.add_mesh(surf, smooth_shading=True)
plotter.show_grid()
plotter.show(interactive=False)
# Out:
# Widget(value='<iframe src="http://localhost:38203/index.html?ui=P_0x779bd80d30e0_21&reconnect=auto" class="pyv…
